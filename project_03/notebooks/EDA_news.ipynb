# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
all_news = pd.read_csv('all-the-news-2-1.csv')
all_news.head()
# Out:
# /Users/scott/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,3,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0 Unnamed: 0.1                 date  year  month day       author  \
# 0           0            0  2016-12-09 18:31:00  2016   12.0   9  Lee Drutman
# 1           1            1  2016-10-07 21:26:46  2016   10.0   7  Scott Davis
# 2           2            2  2018-01-26 00:00:00  2018    1.0  26          NaN
# 3           3            3  2019-06-27 00:00:00  2019    6.0  27          NaN
# 4           4            4  2016-01-27 00:00:00  2016    1.0  27          NaN
#
#                                                title  \
# 0  We should take concerns about the health of li...
# 1  Colts GM Ryan Grigson says Andrew Luck's contr...
# 2       Trump denies report he ordered Mueller fired
# ...

# %%
data = pd.read_csv('./COVID_news_with_dom_topics.csv',index_col='date',parse_dates=['date'])
data.head()
# Out:
#             Unnamed: 0                                              title  \
# date
# 2020-01-01           0  Carolyn Hax: A stay-at-home mom feels hurt whe...
# 2020-01-02           1  Foreign exchange firm Travelex hit by software...
# 2020-01-02           2  Foreign exchange firm Travelex hit by software...
# 2020-01-08           3  China pneumonia outbreak may be linked to new ...
# 2020-01-08           4  WHO says new virus may have caused China pneum...
#
#                                                       article        section  \
# date
# 2020-01-01  Hi, Carolyn: I am a stay-at-home mom of childr...            NaN
# 2020-01-02  LONDON (Reuters) - Foreign exchange firm Trave...  Internet News
# 2020-01-02  LONDON (Reuters) - Foreign exchange firm Trave...  Internet News
# 2020-01-08  LONDON, Jan 8 (Reuters) - A cluster of more th...     Credit RSS
# 2020-01-08  A cluster of more than 50 pneumonia cases in C...    Health News
#
#                 publication  dom_topic
# ...

# %%
all_news.publication.value_counts().plot(kind='bar')
#data.publication.value_counts().plot(kind='bar')

# %%
data.publication.value_counts().plot(kind='bar')

# %%
(data.publication.value_counts()/all_news[all_news.year ==2020].publication.value_counts()).sort_values(ascending = False).plot(kind='bar')

# %%
data[data.dom_topic==17].groupby('date').count().dom_topic.plot()

# %%
data[data.dom_topic==23].groupby('date').count().dom_topic.plot()

# %%
data[data.dom_topic==19].groupby('date').count().dom_topic.plot()

# %%
data[data.dom_topic==12].groupby('date').count().dom_topic.plot()

# %%
# China Wuhan
data[data.dom_topic==11].groupby('date').count().dom_topic.plot()
