# %%
import os
import sys
import json
import pandas as pd
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
TOP_PATH = os.environ['PWD']

# %%
sys.path.append(TOP_PATH + '/src')
sys.path.append(TOP_PATH + '/cfg')

# %%
import etl
from trends import *
from cleaning import clean_2014_2016
from cleaning import clean_2017
import cleaning

# %%
df_2018 = pd.read_csv(TOP_PATH + '/data/raw/STOPS_2018-2019.csv')

# %%
z = cleaning.clean_2018_2019(TOP_PATH + '/data/raw/STOPS_2018-2019.csv')

# %%
z.head()
# Out:
#    stop_id            stop_cause  beat service_area       subject_race  \
# 0     2443  Reasonable Suspicion   122          120              White
# 1     2444     Traffic Violation   121          120              White
# 2     2447  Reasonable Suspicion   822          820  Hispanic/Latino/a
# 3     2448     Traffic Violation   614          610              White
# 4     2449  Reasonable Suspicion   115          110              White
#
#   subject_sex  subject_age   date_stop time_stop arrested searched  \
# 0        Male           25  2018-07-01  00:01:37        Y        N
# 1        Male           25  2018-07-01  00:03:34        N        N
# 2        Male           30  2018-07-01  00:05:43        N        N
# 3        Male           23  2018-07-01  00:19:06        N        N
# 4        Male           25  2018-07-01  00:03:00        Y        Y
#
#   obtained_consent contraband_found property_seized
# 0              NaN                N               N
# ...

# %%
v = pd.read_csv(TOP_PATH + '/data/cleaned/2016_cleaned.csv')

# %%
v.head()
# Out:
#    stop_id           stop_cause service_area       subject_race subject_sex  \
# 0  1444799     Moving Violation          120    Native American        Male
# 1  1444867  Equipment Violation          120              White        Male
# 2  1444871  Equipment Violation          310              Other        Male
# 3  1444869     Moving Violation          620              White        Male
# 4  1444888     Moving Violation          710  Hispanic/Latino/a      Female
#
#    subject_age   date_stop  time_stop arrested searched obtained_consent  \
# 0         37.0  2017-01-01   00:03:00        N        N              NaN
# 1         24.0  2017-01-01   19:15:00        N        N              NaN
# 2         32.0  2017-01-01   19:10:00        N        N              NaN
# 3         31.0  2017-01-01   19:10:00        N        N              NaN
# 4         67.0  2017-01-01   18:50:00        N        N              NaN
#
#   contraband_found property_seized
# ...
